# %% [markdown]
# # Get rows with only latest transaction
#
# - Use the zillow dataset
# - Acquire data from mySQL using the python module to connect and query. You will want to end with a single dataframe. Make sure to include: the logerror, all fields related to the properties that are available. You will end up using all the tables in the database.
# - Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid.
#
# - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction.
#
# - Only include properties that include a latitude and longitude value.
#
#
# ## Solution
# 1. GroupBy parcelid
# 2. Take the max transaction date from the groupby object (a Series)
# 3. Turn the max transaction date by parcel Series into a dataframe
# 4. Merge/join the max transaction date series dataframe with the original dataframe to filter out older transaction dates

# %%
import pandas as pd
from env import get_db_url
url = get_db_url('zillow')

# %%
sql = """
SELECT *
FROM properties_2017
JOIN predictions_2017 using(parcelid)
LEFT JOIN airconditioningtype air USING (airconditioningtypeid) 
LEFT JOIN architecturalstyletype arch USING (architecturalstyletypeid) 
LEFT JOIN buildingclasstype build USING (buildingclasstypeid) 
LEFT JOIN heatingorsystemtype heat USING (heatingorsystemtypeid) 
LEFT JOIN propertylandusetype landuse USING (propertylandusetypeid) 
LEFT JOIN storytype story USING (storytypeid) 
LEFT JOIN typeconstructiontype construct USING (typeconstructiontypeid) 
WHERE latitude IS NOT NULL AND longitude IS NOT NULL
AND transactiondate < '2018-01-01'
"""

df = pd.read_sql(sql, url)
df
# Out:
#        typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0                         NaN          NaN                  261.0
# 1                         NaN          NaN                  261.0
# 2                         NaN          NaN                  261.0
# 3                         NaN          NaN                  261.0
# 4                         NaN          NaN                  266.0
# ...                       ...          ...                    ...
# 77574                     NaN          NaN                  266.0
# 77575                     NaN          NaN                  261.0
# 77576                     NaN          NaN                  261.0
# 77577                     NaN          NaN                  261.0
# 77578                     NaN          NaN                  261.0
#
#        heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                        NaN                  NaN                       NaN
# 1                        NaN                  NaN                       NaN
# 2                        NaN                  NaN                       NaN
# 3                        2.0                  NaN                       NaN
# 4                        2.0                  NaN                       NaN
# ...                      ...                  ...                       ...
# 77574                    2.0                  NaN                       NaN
# 77575                    2.0                  NaN                       NaN
# 77576                    NaN                  NaN                       NaN
# 77577                    2.0                  NaN                       NaN
# 77578                    2.0                  NaN                       NaN
#
#        airconditioningtypeid  parcelid       id  basementsqft  ...     id  \
# 0                        NaN  14297519  1727539           NaN  ...      0
# 1                        NaN  17052889  1387261           NaN  ...      1
# 2                        NaN  14186244    11677           NaN  ...      2
# 3                        NaN  12177905  2288172           NaN  ...      3
# 4                        1.0  10887214  1970746           NaN  ...      4
# ...                      ...       ...      ...           ...  ...    ...
# 77574                    1.0  10833991  2864704           NaN  ...  77608
# 77575                    NaN  11000655   673515           NaN  ...  77609
# 77576                    NaN  17239384  2968375           NaN  ...  77610
# 77577                    1.0  12773139  1843709           NaN  ...  77611
# 77578                    NaN  12826780  1187175           NaN  ...  77612
#
#        logerror  transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0      0.025595       2017-01-01                 None                    None
# 1      0.055619       2017-01-01                 None                    None
# 2      0.005383       2017-01-01                 None                    None
# 3     -0.103410       2017-01-01                 None                    None
# 4      0.006940       2017-01-01              Central                    None
# ...         ...              ...                  ...                     ...
# 77574 -0.002245       2017-09-20              Central                    None
# 77575  0.020615       2017-09-20                 None                    None
# 77576  0.013209       2017-09-21                 None                    None
# 77577  0.037129       2017-09-21              Central                    None
# 77578  0.007204       2017-09-25                 None                    None
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                   None                 None  Single Family Residential
# 1                   None                 None  Single Family Residential
# 2                   None                 None  Single Family Residential
# 3                   None              Central  Single Family Residential
# 4                   None              Central                Condominium
# ...                  ...                  ...                        ...
# 77574               None              Central                Condominium
# 77575               None              Central  Single Family Residential
# 77576               None                 None  Single Family Residential
# 77577               None              Central  Single Family Residential
# 77578               None              Central  Single Family Residential
#
#        storydesc  typeconstructiondesc
# 0           None                  None
# 1           None                  None
# 2           None                  None
# 3           None                  None
# 4           None                  None
# ...          ...                   ...
# 77574       None                  None
# 77575       None                  None
# 77576       None                  None
# 77577       None                  None
# 77578       None                  None
#
# [77579 rows x 69 columns]

# %%
n_duplicates = df.parcelid.duplicated().sum()
n_duplicates
# Out:
# 198

# %%
# Convert transaction date into proper datetime format
df.transactiondate = pd.to_datetime(df.transactiondate)

# %%
# Obtain the maximimum transaction date by each parcelid
# For parcelids that show once, this returns the only transactiondate
# For parcelids showing multiple times, this returns the max transactiondate
max_transaction_date_by_parcel = df.groupby('parcelid').transactiondate.max()
max_transaction_date_by_parcel
# Out:
# parcelid
# 10711855    2017-07-07
# 10711877    2017-08-29
# 10711888    2017-04-04
# 10711910    2017-03-17
# 10711923    2017-03-24
#                ...
# 167686999   2017-02-28
# 167687739   2017-03-03
# 167687839   2017-05-31
# 167688532   2017-02-03
# 167689317   2017-03-14
# Name: transactiondate, Length: 77381, dtype: datetime64[ns]

# %%
# Convert the above Series into a Dataframe
max_transaction_date_by_parcel = pd.DataFrame(max_transaction_date_by_parcel)
max_transaction_date_by_parcel['parcelid'] = max_transaction_date_by_parcel.index
max_transaction_date_by_parcel = max_transaction_date_by_parcel.reset_index(drop=True)
max_transaction_date_by_parcel
# Out:
#       transactiondate   parcelid
# 0          2017-07-07   10711855
# 1          2017-08-29   10711877
# 2          2017-04-04   10711888
# 3          2017-03-17   10711910
# 4          2017-03-24   10711923
# ...               ...        ...
# 77376      2017-02-28  167686999
# 77377      2017-03-03  167687739
# 77378      2017-05-31  167687839
# 77379      2017-02-03  167688532
# 77380      2017-03-14  167689317
#
# [77381 rows x 2 columns]

# %%
# Merge/join on both the transaction date AND parcel id in order to filter out the older transactiondates by parcel
# The merge/join is where the "magic" happens of removing rows with duplicate parcelids w/ less recent transactiondates
output = df.merge(max_transaction_date_by_parcel, on=["transactiondate", "parcelid"])
output
# Out:
#        typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0                         NaN          NaN                  261.0
# 1                         NaN          NaN                  261.0
# 2                         NaN          NaN                  261.0
# 3                         NaN          NaN                  261.0
# 4                         NaN          NaN                  266.0
# ...                       ...          ...                    ...
# 77376                     NaN          NaN                  266.0
# 77377                     NaN          NaN                  261.0
# 77378                     NaN          NaN                  261.0
# 77379                     NaN          NaN                  261.0
# 77380                     NaN          NaN                  261.0
#
#        heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                        NaN                  NaN                       NaN
# 1                        NaN                  NaN                       NaN
# 2                        NaN                  NaN                       NaN
# 3                        2.0                  NaN                       NaN
# 4                        2.0                  NaN                       NaN
# ...                      ...                  ...                       ...
# 77376                    2.0                  NaN                       NaN
# 77377                    2.0                  NaN                       NaN
# 77378                    NaN                  NaN                       NaN
# 77379                    2.0                  NaN                       NaN
# 77380                    2.0                  NaN                       NaN
#
#        airconditioningtypeid  parcelid       id  basementsqft  ...     id  \
# 0                        NaN  14297519  1727539           NaN  ...      0
# 1                        NaN  17052889  1387261           NaN  ...      1
# 2                        NaN  14186244    11677           NaN  ...      2
# 3                        NaN  12177905  2288172           NaN  ...      3
# 4                        1.0  10887214  1970746           NaN  ...      4
# ...                      ...       ...      ...           ...  ...    ...
# 77376                    1.0  10833991  2864704           NaN  ...  77608
# 77377                    NaN  11000655   673515           NaN  ...  77609
# 77378                    NaN  17239384  2968375           NaN  ...  77610
# 77379                    1.0  12773139  1843709           NaN  ...  77611
# 77380                    NaN  12826780  1187175           NaN  ...  77612
#
#        logerror  transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0      0.025595       2017-01-01                 None                    None
# 1      0.055619       2017-01-01                 None                    None
# 2      0.005383       2017-01-01                 None                    None
# 3     -0.103410       2017-01-01                 None                    None
# 4      0.006940       2017-01-01              Central                    None
# ...         ...              ...                  ...                     ...
# 77376 -0.002245       2017-09-20              Central                    None
# 77377  0.020615       2017-09-20                 None                    None
# 77378  0.013209       2017-09-21                 None                    None
# 77379  0.037129       2017-09-21              Central                    None
# 77380  0.007204       2017-09-25                 None                    None
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                   None                 None  Single Family Residential
# 1                   None                 None  Single Family Residential
# 2                   None                 None  Single Family Residential
# 3                   None              Central  Single Family Residential
# 4                   None              Central                Condominium
# ...                  ...                  ...                        ...
# 77376               None              Central                Condominium
# 77377               None              Central  Single Family Residential
# 77378               None                 None  Single Family Residential
# 77379               None              Central  Single Family Residential
# 77380               None              Central  Single Family Residential
#
#        storydesc  typeconstructiondesc
# 0           None                  None
# 1           None                  None
# 2           None                  None
# 3           None                  None
# 4           None                  None
# ...          ...                   ...
# 77376       None                  None
# 77377       None                  None
# 77378       None                  None
# 77379       None                  None
# 77380       None                  None
#
# [77381 rows x 69 columns]

# %%
assert n_duplicates == (df.shape[0] - output.shape[0])
print("Number of duplicates is equal to the length of the original dataframe minus the length of the final dataframe")
# Out:
# Number of duplicates is equal to the length of the original dataframe minus the length of the final dataframe

# %%
output.parcelid.duplicated().sum()
# Out:
# 0

# %%
assert output.parcelid.duplicated().sum() == 0
print("No duplicate parcelid values in the final dataframe")
# Out:
# No duplicate parcelid values in the final dataframe
