# %% [markdown]
# # Get rows with only latest transaction
#
# - Use the zillow dataset
# - Acquire data from mySQL using the python module to connect and query. You will want to end with a single dataframe. Make sure to include: the logerror, all fields related to the properties that are available. You will end up using all the tables in the database.
# - Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid.
#
# - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction.
#
# - Only include properties that include a latitude and longitude value.
#
#
# ### Thoughts
# - Isolate a dataframe of the rows with no duplicated parcelids
# - Isolate a dataframe w/ duplicated parcelids
#     - Then filter to have only the most recent transaction data
# - Concatenate those two dataframes together
# - Profit!

# %%
import pandas as pd
from env import get_db_url
url = get_db_url('zillow')

# %%
sql = """
select *
from properties_2017
join predictions_2017 using(parcelid)
where latitude is not null and longitude is not null
and transactiondate <= '2017-12-31'
"""

df = pd.read_sql(sql, url)
df
# Out:
#        parcelid       id  airconditioningtypeid  architecturalstyletypeid  \
# 0      14297519  1727539                    NaN                       NaN
# 1      17052889  1387261                    NaN                       NaN
# 2      14186244    11677                    NaN                       NaN
# 3      12177905  2288172                    NaN                       NaN
# 4      10887214  1970746                    1.0                       NaN
# ...         ...      ...                    ...                       ...
# 77574  10833991  2864704                    1.0                       NaN
# 77575  11000655   673515                    NaN                       NaN
# 77576  17239384  2968375                    NaN                       NaN
# 77577  12773139  1843709                    1.0                       NaN
# 77578  12826780  1187175                    NaN                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0               NaN          3.5         4.0                  NaN
# 1               NaN          1.0         2.0                  NaN
# 2               NaN          2.0         3.0                  NaN
# 3               NaN          3.0         4.0                  NaN
# 4               NaN          3.0         3.0                  NaN
# ...             ...          ...         ...                  ...
# 77574           NaN          3.0         3.0                  NaN
# 77575           NaN          2.0         2.0                  NaN
# 77576           NaN          2.0         4.0                  NaN
# 77577           NaN          1.0         3.0                  NaN
# 77578           NaN          2.0         3.0                  NaN
#
#        buildingqualitytypeid  calculatedbathnbr  ...  taxvaluedollarcnt  \
# 0                        NaN                3.5  ...          1023282.0
# 1                        NaN                1.0  ...           464000.0
# 2                        NaN                2.0  ...           564778.0
# 3                        8.0                3.0  ...           145143.0
# 4                        8.0                3.0  ...           119407.0
# ...                      ...                ...  ...                ...
# 77574                    8.0                3.0  ...           379000.0
# 77575                    6.0                2.0  ...           354621.0
# 77576                    NaN                2.0  ...            67205.0
# 77577                    4.0                1.0  ...            49546.0
# 77578                    6.0                2.0  ...           522000.0
#
#        assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0              2016.0               537569.0   11013.72                None
# 1              2016.0               376000.0    5672.48                None
# 2              2016.0               479489.0    6488.30                None
# 3              2016.0                36225.0    1777.51                None
# 4              2016.0                45726.0    1533.89                None
# ...               ...                    ...        ...                 ...
# 77574          2016.0               114000.0    4685.34                None
# 77575          2016.0               283704.0    4478.43                None
# 77576          2016.0                16522.0    1107.48                None
# 77577          2016.0                16749.0     876.43                None
# 77578          2016.0               382000.0    6317.15                None
#
#        taxdelinquencyyear  censustractandblock     id  logerror  \
# 0                     NaN         6.059063e+13      0  0.025595
# 1                     NaN         6.111001e+13      1  0.055619
# 2                     NaN         6.059022e+13      2  0.005383
# 3                     NaN         6.037300e+13      3 -0.103410
# 4                     NaN         6.037124e+13      4  0.006940
# ...                   ...                  ...    ...       ...
# 77574                 NaN         6.037132e+13  77608 -0.002245
# 77575                 NaN         6.037101e+13  77609  0.020615
# 77576                 NaN         6.111008e+13  77610  0.013209
# 77577                 NaN         6.037434e+13  77611  0.037129
# 77578                 NaN         6.037503e+13  77612  0.007204
#
#        transactiondate
# 0           2017-01-01
# 1           2017-01-01
# 2           2017-01-01
# 3           2017-01-01
# 4           2017-01-01
# ...                ...
# 77574       2017-09-20
# 77575       2017-09-20
# 77576       2017-09-21
# 77577       2017-09-21
# 77578       2017-09-25
#
# [77579 rows x 62 columns]

# %%
# Rows with no duplicates
no_duplicates = df[~df.parcelid.duplicated()]
no_duplicates
# Out:
#        parcelid       id  airconditioningtypeid  architecturalstyletypeid  \
# 0      14297519  1727539                    NaN                       NaN
# 1      17052889  1387261                    NaN                       NaN
# 2      14186244    11677                    NaN                       NaN
# 3      12177905  2288172                    NaN                       NaN
# 4      10887214  1970746                    1.0                       NaN
# ...         ...      ...                    ...                       ...
# 77574  10833991  2864704                    1.0                       NaN
# 77575  11000655   673515                    NaN                       NaN
# 77576  17239384  2968375                    NaN                       NaN
# 77577  12773139  1843709                    1.0                       NaN
# 77578  12826780  1187175                    NaN                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0               NaN          3.5         4.0                  NaN
# 1               NaN          1.0         2.0                  NaN
# 2               NaN          2.0         3.0                  NaN
# 3               NaN          3.0         4.0                  NaN
# 4               NaN          3.0         3.0                  NaN
# ...             ...          ...         ...                  ...
# 77574           NaN          3.0         3.0                  NaN
# 77575           NaN          2.0         2.0                  NaN
# 77576           NaN          2.0         4.0                  NaN
# 77577           NaN          1.0         3.0                  NaN
# 77578           NaN          2.0         3.0                  NaN
#
#        buildingqualitytypeid  calculatedbathnbr  ...  taxvaluedollarcnt  \
# 0                        NaN                3.5  ...          1023282.0
# 1                        NaN                1.0  ...           464000.0
# 2                        NaN                2.0  ...           564778.0
# 3                        8.0                3.0  ...           145143.0
# 4                        8.0                3.0  ...           119407.0
# ...                      ...                ...  ...                ...
# 77574                    8.0                3.0  ...           379000.0
# 77575                    6.0                2.0  ...           354621.0
# 77576                    NaN                2.0  ...            67205.0
# 77577                    4.0                1.0  ...            49546.0
# 77578                    6.0                2.0  ...           522000.0
#
#        assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0              2016.0               537569.0   11013.72                None
# 1              2016.0               376000.0    5672.48                None
# 2              2016.0               479489.0    6488.30                None
# 3              2016.0                36225.0    1777.51                None
# 4              2016.0                45726.0    1533.89                None
# ...               ...                    ...        ...                 ...
# 77574          2016.0               114000.0    4685.34                None
# 77575          2016.0               283704.0    4478.43                None
# 77576          2016.0                16522.0    1107.48                None
# 77577          2016.0                16749.0     876.43                None
# 77578          2016.0               382000.0    6317.15                None
#
#        taxdelinquencyyear  censustractandblock     id  logerror  \
# 0                     NaN         6.059063e+13      0  0.025595
# 1                     NaN         6.111001e+13      1  0.055619
# 2                     NaN         6.059022e+13      2  0.005383
# 3                     NaN         6.037300e+13      3 -0.103410
# 4                     NaN         6.037124e+13      4  0.006940
# ...                   ...                  ...    ...       ...
# 77574                 NaN         6.037132e+13  77608 -0.002245
# 77575                 NaN         6.037101e+13  77609  0.020615
# 77576                 NaN         6.111008e+13  77610  0.013209
# 77577                 NaN         6.037434e+13  77611  0.037129
# 77578                 NaN         6.037503e+13  77612  0.007204
#
#        transactiondate
# 0           2017-01-01
# 1           2017-01-01
# 2           2017-01-01
# 3           2017-01-01
# 4           2017-01-01
# ...                ...
# 77574       2017-09-20
# 77575       2017-09-20
# 77576       2017-09-21
# 77577       2017-09-21
# 77578       2017-09-25
#
# [77381 rows x 62 columns]

# %%
# 198 duplicated parcelids
df.parcelid.duplicated().sum()
# Out:
# 198

# %%
df.groupby('parcelid').parcelid.count()[df.groupby('parcelid').parcelid.count() > 1]
# Out:
# parcelid
# 10722858     2
# 10732347     2
# 10739478     2
# 10744507     2
# 10753427     2
#             ..
# 17251843     2
# 17280166     2
# 17282392     2
# 17295416     2
# 162960529    2
# Name: parcelid, Length: 195, dtype: int64

# %%
# Number of times each parcelid shows in this dataframe
df.groupby('parcelid').parcelid.count().sort_values(ascending=False)
# Out:
# parcelid
# 10857130     3
# 11991059     3
# 12612211     3
# 11739891     2
# 11577176     2
#             ..
# 11876038     1
# 11876013     1
# 11875917     1
# 11875901     1
# 167689317    1
# Name: parcelid, Length: 77381, dtype: int64

# %%
# Generate a series of unique parcelids that have been duplicated
duplicate_parcelids = df[df.parcelid.duplicated()].parcelid
duplicate_parcelids
# Out:
# 117      11393337
# 624      14634203
# 1017     11721753
# 1246     11289917
# 1732     11637029
#            ...
# 59986    13066981
# 62214    10852812
# 63107    12136147
# 64253    17282392
# 64918    10984080
# Name: parcelid, Length: 198, dtype: int64

# %%
# All the rows with a parcelid showing up more than once
rows_with_duplicate_parcelids = df[df.parcelid.isin(duplicate_parcelids)]
rows_with_duplicate_parcelids
# Out:
#        parcelid       id  airconditioningtypeid  architecturalstyletypeid  \
# 116    11393337  2463969                    NaN                       NaN
# 117    11393337  2463969                    NaN                       NaN
# 623    14634203  2026522                    1.0                       NaN
# 624    14634203  2026522                    1.0                       NaN
# 1016   11721753   616260                    NaN                       NaN
# ...         ...      ...                    ...                       ...
# 63107  12136147  2407178                    NaN                       NaN
# 64252  17282392  2938730                    NaN                       NaN
# 64253  17282392  2938730                    NaN                       NaN
# 64917  10984080  2876815                    1.0                       NaN
# 64918  10984080  2876815                    1.0                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 116             NaN          3.0         3.0                  NaN
# 117             NaN          3.0         3.0                  NaN
# 623             NaN          2.0         3.0                  NaN
# 624             NaN          2.0         3.0                  NaN
# 1016            NaN          2.0         3.0                  NaN
# ...             ...          ...         ...                  ...
# 63107           NaN          2.0         3.0                  NaN
# 64252           NaN          2.0         3.0                  NaN
# 64253           NaN          2.0         3.0                  NaN
# 64917           NaN          3.0         3.0                  NaN
# 64918           NaN          3.0         3.0                  NaN
#
#        buildingqualitytypeid  calculatedbathnbr  ...  taxvaluedollarcnt  \
# 116                      4.0                3.0  ...            43439.0
# 117                      4.0                3.0  ...            43439.0
# 623                      NaN                2.0  ...           289445.0
# 624                      NaN                2.0  ...           289445.0
# 1016                     6.0                2.0  ...           205123.0
# ...                      ...                ...  ...                ...
# 63107                    5.0                2.0  ...           775383.0
# 64252                    NaN                2.0  ...           498684.0
# 64253                    NaN                2.0  ...           498684.0
# 64917                    8.0                3.0  ...           354000.0
# 64918                    8.0                3.0  ...           354000.0
#
#        assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 116            2016.0                22755.0     756.94                   Y
# 117            2016.0                22755.0     756.94                   Y
# 623            2016.0               213516.0    3490.16                None
# 624            2016.0               213516.0    3490.16                None
# 1016           2016.0               163175.0    2627.48                None
# ...               ...                    ...        ...                 ...
# 63107          2016.0               608190.0    9103.61                None
# 64252          2016.0               249342.0    5258.54                None
# 64253          2016.0               249342.0    5258.54                None
# 64917          2016.0               141000.0    4347.32                   Y
# 64918          2016.0               141000.0    4347.32                   Y
#
#        taxdelinquencyyear  censustractandblock     id  logerror  \
# 116                  14.0         6.037235e+13    116  0.015172
# 117                  14.0         6.037235e+13    117  0.086137
# 623                   NaN         6.059001e+13    624 -0.019491
# 624                   NaN         6.059001e+13    625 -0.061973
# 1016                  NaN         6.037220e+13   1017 -0.011052
# ...                   ...                  ...    ...       ...
# 63107                 NaN         6.037431e+13  63132 -0.078758
# 64252                 NaN         6.111007e+13  64277 -0.002968
# 64253                 NaN         6.111007e+13  64278  0.901074
# 64917                15.0         6.037104e+13  64943  0.001824
# 64918                15.0         6.037104e+13  64944  0.860596
#
#        transactiondate
# 116         2017-01-03
# 117         2017-06-08
# 623         2017-01-04
# 624         2017-08-04
# 1016        2017-01-05
# ...                ...
# 63107       2017-08-31
# 64252       2017-08-07
# 64253       2017-08-25
# 64917       2017-08-09
# 64918       2017-09-12
#
# [393 rows x 62 columns]

# %%
# Obtain the latest transaction date for each parcelid
latest = pd.DataFrame(rows_with_duplicate_parcelids.groupby("parcelid").transactiondate.max())
latest["parcelid"] = latest.index
latest = latest.reset_index(drop=True)
latest
# Out:
#     transactiondate   parcelid
# 0        2017-07-28   10722858
# 1        2017-07-25   10732347
# 2        2017-03-31   10739478
# 3        2017-08-31   10744507
# 4        2017-03-17   10753427
# ..              ...        ...
# 190      2017-06-22   17251843
# 191      2017-06-15   17280166
# 192      2017-08-25   17282392
# 193      2017-05-16   17295416
# 194      2017-05-26  162960529
#
# [195 rows x 2 columns]

# %%
only_latest = rows_with_duplicate_parcelids.merge(latest, on=["transactiondate", "parcelid"])
only_latest
# Out:
#      parcelid       id  airconditioningtypeid  architecturalstyletypeid  \
# 0    11393337  2463969                    NaN                       NaN
# 1    14634203  2026522                    1.0                       NaN
# 2    11721753   616260                    NaN                       NaN
# 3    11289917  2061546                    1.0                       NaN
# 4    11637029  2554497                    1.0                       NaN
# ..        ...      ...                    ...                       ...
# 190  13066981  2008746                    1.0                       NaN
# 191  10852812   492024                    NaN                       NaN
# 192  12136147  2407178                    NaN                       NaN
# 193  17282392  2938730                    NaN                       NaN
# 194  10984080  2876815                    1.0                       NaN
#
#      basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0             NaN          3.0         3.0                  NaN
# 1             NaN          2.0         3.0                  NaN
# 2             NaN          2.0         3.0                  NaN
# 3             NaN          2.0         3.0                  NaN
# 4             NaN          2.0         3.0                  NaN
# ..            ...          ...         ...                  ...
# 190           NaN          2.0         4.0                  NaN
# 191           NaN          7.0        11.0                  NaN
# 192           NaN          2.0         3.0                  NaN
# 193           NaN          2.0         3.0                  NaN
# 194           NaN          3.0         3.0                  NaN
#
#      buildingqualitytypeid  calculatedbathnbr  ...  taxvaluedollarcnt  \
# 0                      4.0                3.0  ...            43439.0
# 1                      NaN                2.0  ...           289445.0
# 2                      6.0                2.0  ...           205123.0
# 3                      6.0                2.0  ...           136104.0
# 4                      9.0                2.0  ...           810694.0
# ..                     ...                ...  ...                ...
# 190                    8.0                2.0  ...           366160.0
# 191                    8.0                7.0  ...          5373376.0
# 192                    5.0                2.0  ...           775383.0
# 193                    NaN                2.0  ...           498684.0
# 194                    8.0                3.0  ...           354000.0
#
#      assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0            2016.0                22755.0     756.94                   Y
# 1            2016.0               213516.0    3490.16                None
# 2            2016.0               163175.0    2627.48                None
# 3            2016.0                27214.0    2319.90                   Y
# 4            2016.0               554156.0    9407.01                   Y
# ..              ...                    ...        ...                 ...
# 190          2016.0               174133.0    4872.87                None
# 191          2016.0              1923376.0   64396.38                None
# 192          2016.0               608190.0    9103.61                None
# 193          2016.0               249342.0    5258.54                None
# 194          2016.0               141000.0    4347.32                   Y
#
#      taxdelinquencyyear  censustractandblock     id  logerror  transactiondate
# 0                  14.0         6.037235e+13    117  0.086137       2017-06-08
# 1                   NaN         6.059001e+13    625 -0.061973       2017-08-04
# 2                   NaN         6.037220e+13   1018  0.017785       2017-07-21
# 3                  15.0         6.037901e+13   1248 -0.362001       2017-06-23
# 4                  13.0         6.037701e+13   1734 -0.093399       2017-07-28
# ..                  ...                  ...    ...       ...              ...
# 190                 NaN         6.037403e+13  60010 -0.043423       2017-09-01
# 191                 NaN                  NaN  62239  2.237069       2017-08-31
# 192                 NaN         6.037431e+13  63132 -0.078758       2017-08-31
# 193                 NaN         6.111007e+13  64278  0.901074       2017-08-25
# 194                15.0         6.037104e+13  64944  0.860596       2017-09-12
#
# [195 rows x 62 columns]

# %%
final = pd.concat([only_latest, no_duplicates])
final
# Out:
#        parcelid       id  airconditioningtypeid  architecturalstyletypeid  \
# 0      11393337  2463969                    NaN                       NaN
# 1      14634203  2026522                    1.0                       NaN
# 2      11721753   616260                    NaN                       NaN
# 3      11289917  2061546                    1.0                       NaN
# 4      11637029  2554497                    1.0                       NaN
# ...         ...      ...                    ...                       ...
# 77574  10833991  2864704                    1.0                       NaN
# 77575  11000655   673515                    NaN                       NaN
# 77576  17239384  2968375                    NaN                       NaN
# 77577  12773139  1843709                    1.0                       NaN
# 77578  12826780  1187175                    NaN                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0               NaN          3.0         3.0                  NaN
# 1               NaN          2.0         3.0                  NaN
# 2               NaN          2.0         3.0                  NaN
# 3               NaN          2.0         3.0                  NaN
# 4               NaN          2.0         3.0                  NaN
# ...             ...          ...         ...                  ...
# 77574           NaN          3.0         3.0                  NaN
# 77575           NaN          2.0         2.0                  NaN
# 77576           NaN          2.0         4.0                  NaN
# 77577           NaN          1.0         3.0                  NaN
# 77578           NaN          2.0         3.0                  NaN
#
#        buildingqualitytypeid  calculatedbathnbr  ...  taxvaluedollarcnt  \
# 0                        4.0                3.0  ...            43439.0
# 1                        NaN                2.0  ...           289445.0
# 2                        6.0                2.0  ...           205123.0
# 3                        6.0                2.0  ...           136104.0
# 4                        9.0                2.0  ...           810694.0
# ...                      ...                ...  ...                ...
# 77574                    8.0                3.0  ...           379000.0
# 77575                    6.0                2.0  ...           354621.0
# 77576                    NaN                2.0  ...            67205.0
# 77577                    4.0                1.0  ...            49546.0
# 77578                    6.0                2.0  ...           522000.0
#
#        assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0              2016.0                22755.0     756.94                   Y
# 1              2016.0               213516.0    3490.16                None
# 2              2016.0               163175.0    2627.48                None
# 3              2016.0                27214.0    2319.90                   Y
# 4              2016.0               554156.0    9407.01                   Y
# ...               ...                    ...        ...                 ...
# 77574          2016.0               114000.0    4685.34                None
# 77575          2016.0               283704.0    4478.43                None
# 77576          2016.0                16522.0    1107.48                None
# 77577          2016.0                16749.0     876.43                None
# 77578          2016.0               382000.0    6317.15                None
#
#        taxdelinquencyyear  censustractandblock     id  logerror  \
# 0                    14.0         6.037235e+13    117  0.086137
# 1                     NaN         6.059001e+13    625 -0.061973
# 2                     NaN         6.037220e+13   1018  0.017785
# 3                    15.0         6.037901e+13   1248 -0.362001
# 4                    13.0         6.037701e+13   1734 -0.093399
# ...                   ...                  ...    ...       ...
# 77574                 NaN         6.037132e+13  77608 -0.002245
# 77575                 NaN         6.037101e+13  77609  0.020615
# 77576                 NaN         6.111008e+13  77610  0.013209
# 77577                 NaN         6.037434e+13  77611  0.037129
# 77578                 NaN         6.037503e+13  77612  0.007204
#
#        transactiondate
# 0           2017-06-08
# 1           2017-08-04
# 2           2017-07-21
# 3           2017-06-23
# 4           2017-07-28
# ...                ...
# 77574       2017-09-20
# 77575       2017-09-20
# 77576       2017-09-21
# 77577       2017-09-21
# 77578       2017-09-25
#
# [77576 rows x 62 columns]

# %%
final.parcelid.duplicated().sum()
# Out:
# 195

# %%
no_duplicates.parcelid.duplicated().sum()
# Out:
# 0

# %%
only_latest.parcelid.duplicated().sum()
# Out:
# 0

# %%
# Looks like I still have an issue with the logic of this approach.
# TODO: revisit my approach
final[final.parcelid.duplicated()]
# Out:
#        parcelid       id  airconditioningtypeid  architecturalstyletypeid  \
# 116    11393337  2463969                    NaN                       NaN
# 623    14634203  2026522                    1.0                       NaN
# 1016   11721753   616260                    NaN                       NaN
# 1245   11289917  2061546                    1.0                       NaN
# 1731   11637029  2554497                    1.0                       NaN
# ...         ...      ...                    ...                       ...
# 59985  13066981  2008746                    1.0                       NaN
# 62213  10852812   492024                    NaN                       NaN
# 63106  12136147  2407178                    NaN                       NaN
# 64252  17282392  2938730                    NaN                       NaN
# 64917  10984080  2876815                    1.0                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 116             NaN          3.0         3.0                  NaN
# 623             NaN          2.0         3.0                  NaN
# 1016            NaN          2.0         3.0                  NaN
# 1245            NaN          2.0         3.0                  NaN
# 1731            NaN          2.0         3.0                  NaN
# ...             ...          ...         ...                  ...
# 59985           NaN          2.0         4.0                  NaN
# 62213           NaN          7.0        11.0                  NaN
# 63106           NaN          2.0         3.0                  NaN
# 64252           NaN          2.0         3.0                  NaN
# 64917           NaN          3.0         3.0                  NaN
#
#        buildingqualitytypeid  calculatedbathnbr  ...  taxvaluedollarcnt  \
# 116                      4.0                3.0  ...            43439.0
# 623                      NaN                2.0  ...           289445.0
# 1016                     6.0                2.0  ...           205123.0
# 1245                     6.0                2.0  ...           136104.0
# 1731                     9.0                2.0  ...           810694.0
# ...                      ...                ...  ...                ...
# 59985                    8.0                2.0  ...           366160.0
# 62213                    8.0                7.0  ...          5373376.0
# 63106                    5.0                2.0  ...           775383.0
# 64252                    NaN                2.0  ...           498684.0
# 64917                    8.0                3.0  ...           354000.0
#
#        assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 116            2016.0                22755.0     756.94                   Y
# 623            2016.0               213516.0    3490.16                None
# 1016           2016.0               163175.0    2627.48                None
# 1245           2016.0                27214.0    2319.90                   Y
# 1731           2016.0               554156.0    9407.01                   Y
# ...               ...                    ...        ...                 ...
# 59985          2016.0               174133.0    4872.87                None
# 62213          2016.0              1923376.0   64396.38                None
# 63106          2016.0               608190.0    9103.61                None
# 64252          2016.0               249342.0    5258.54                None
# 64917          2016.0               141000.0    4347.32                   Y
#
#        taxdelinquencyyear  censustractandblock     id  logerror  \
# 116                  14.0         6.037235e+13    116  0.015172
# 623                   NaN         6.059001e+13    624 -0.019491
# 1016                  NaN         6.037220e+13   1017 -0.011052
# 1245                 15.0         6.037901e+13   1247  0.227903
# 1731                 13.0         6.037701e+13   1733 -0.024199
# ...                   ...                  ...    ...       ...
# 59985                 NaN         6.037403e+13  60009  0.016734
# 62213                 NaN                  NaN  62238  2.027777
# 63106                 NaN         6.037431e+13  63131  0.056067
# 64252                 NaN         6.111007e+13  64277 -0.002968
# 64917                15.0         6.037104e+13  64943  0.001824
#
#        transactiondate
# 116         2017-01-03
# 623         2017-01-04
# 1016        2017-01-05
# 1245        2017-01-06
# 1731        2017-01-09
# ...                ...
# 59985       2017-07-24
# 62213       2017-07-28
# 63106       2017-08-01
# 64252       2017-08-07
# 64917       2017-08-09
#
# [195 rows x 62 columns]
